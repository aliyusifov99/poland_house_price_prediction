# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_train_housing = pd.read_csv(r"C:\MLProjects\poland_house_price_prediction\data\processed\housing\train_housing.csv")
df_test_housing = pd.read_csv(r"C:\MLProjects\poland_house_price_prediction\data\processed\housing\test_housing.csv")
df_train_rent = pd.read_csv(r"C:\MLProjects\poland_house_price_prediction\data\processed\rent\train_rent.csv")
df_test_rent = pd.read_csv(r"C:\MLProjects\poland_house_price_prediction\data\processed\rent\test_rent.csv")

# %%
# null values check
print(df_train_housing.isnull().sum())
print(df_test_housing.isnull().sum())
print(df_train_rent.isnull().sum())
print(df_test_rent.isnull().sum())
# Out:
# city                    0
# type                    0
# squareMeters            0
# rooms                   0
# floor                   0
# floorCount              0
# buildYear               0
# centreDistance          0
# poiCount                0
# schoolDistance          0
# clinicDistance          0
# postOfficeDistance      0
# kindergartenDistance    0
# restaurantDistance      0
# collegeDistance         0
# pharmacyDistance        0
# ownership               0
# buildingMaterial        0
# condition               0
# hasParkingSpace         0
# hasBalcony              0
# hasElevator             0
# hasSecurity             0
# hasStorageRoom          0
# price                   0
# dtype: int64
# city                    0
# type                    0
# squareMeters            0
# rooms                   0
# floor                   0
# floorCount              0
# buildYear               0
# centreDistance          0
# poiCount                0
# schoolDistance          0
# ...

# %%
df_train_housing
# Out:
#         city  type  squareMeters  rooms  floor  floorCount  buildYear  \
# 0         13     1      2.081914    1.0   -1.0   -0.333333   0.000000
# 1         13     1      0.378751    0.0    1.0    0.333333   0.000000
# 2         14     0     -0.168694   -1.0    0.5    0.000000   0.476190
# 3          3     2     -0.300487   -1.0    0.0   -0.333333  -0.928571
# 4         14     1     -0.675588   -1.0    0.5    0.000000  -0.261905
# ...      ...   ...           ...    ...    ...         ...        ...
# 156449     6     2     -0.800487   -2.0   -1.0   -0.666667  -1.761905
# 156450     6     2     -0.229521    0.0   -1.0   -0.666667  -1.047619
# 156451    13     2     -0.326845   -1.0    0.0    1.000000  -1.023810
# 156452     2     1     -0.789132   -1.0   -0.5    0.000000   0.000000
# 156453     9     1     -0.518654    0.0   -0.5   -0.666667   0.357143
#
#         centreDistance  poiCount  schoolDistance  ...  pharmacyDistance  \
# ...
